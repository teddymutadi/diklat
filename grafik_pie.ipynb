# %% [markdown]
# <a href="https://colab.research.google.com/github/teddymutadi/diklat/blob/main/grafik_pie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Membuat Grafik Pie Secara Manual</h1>
#
# ```
# # This is formatted as code
# ```

# %%
import matplotlib.pyplot as plt

# %%
# Data untuk grafik
labels = 'Kategori A', 'Kategori B', 'Kategori C', 'Kategori D'
sizes = [15, 30, 45, 10]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # "Meledakkan" (explode) bagian pertama

# %%
# membuat pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=130)

# menampilkan grafik
plt.show()
